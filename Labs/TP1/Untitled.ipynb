# %%
include("../data/julia/pss0.jl");

# %%
using FFTW

# %%
include("../modules/operations.jl");

# %%
pss_0
# Out:
# 2048-element Vector{Complex{Int64}}:
#  -363 + 0im
#   362 + 0im
#   362 + 0im
#  -363 + 0im
#  -363 + 0im
#   362 + 0im
#  -363 + 0im
#   362 + 0im
#   362 + 0im
#  -363 + 0im
#  -363 + 0im
#  -363 + 0im
#  -363 + 0im
#       ⋮
#   362 + 0im
#   362 + 0im
#  -363 + 0im
#   362 + 0im
#   362 + 0im
#   362 + 0im
#   362 + 0im
#   362 + 0im
#   362 + 0im
#  -363 + 0im
#   362 + 0im
#   362 + 0im

# %%
𝑆̃ₚₛₛ⁰ = Fᴵ(pss_0); # S Slanted (fourier transform) in time domain

# %%
using LinearAlgebra

# %%
𝑆̃ₚₛₛ⁰ ./= norm(𝑆̃ₚₛₛ⁰); @show size(𝑆̃ₚₛₛ⁰); # Normalize the arrays
# Out:
# size(𝑆̃ₚₛₛ⁰) = (2048,)

# %%
𝑆̃ₚₛₛ⁰ = 𝑆̃ₚₛₛ⁰[(end-143):end] ⧺ 𝑆̃ₚₛₛ⁰ ; @show size(𝑆̃ₚₛₛ⁰); # end is 2048 in this case, concat math
# Out:
# size(𝑆̃ₚₛₛ⁰) = (2192,)

# %%
using Plots

# %%
# Plot real part
plot(real(𝑆̃ₚₛₛ⁰)
    , label="I"
    , xlabel="Time (ms)"
    , ylabel="Amplitude"
    , legend=:topright
    , ylims = (-0.05, 0.05)
    , xlims = (0,2500)
    , linewidth = 2
)

# Plot imaginary part
plot!(imag(𝑆̃ₚₛₛ⁰)
    , label="Q"
    , linewidth = 2
)
