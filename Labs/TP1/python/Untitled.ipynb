# %%
import numpy as np
from scipy.signal import resample_poly, firwin, bilinear, lfilter
import matplotlib.pyplot as plt

# Read in signal
x = np.fromfile('data/rxsignal_withchannelandfreqoff.mat', dtype=np.int32)
sample_rate = 250e3
center_freq = 99.5e6

# %%
plt.plot(x)
